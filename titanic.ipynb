# %% [markdown]
# # Eploring Titanic data with GitHub Copilot
# The Titanic dataset

# %%
import pandas as pandas

url = "https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/titanic.csv"

# %%
# Let's have an overview of the data by printing the first 5 rows

# %%
# How many passengers have survived and print the result
# Out:
# 342

# %%
# let's look at the correlation between the columns Survived and Pclass
# and visualize the number of passengers that survived per class
import seaborn as sns
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>
